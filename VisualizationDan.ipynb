# %% [markdown]
# # Scatter Plot Visualization

# %%
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import
import matplotlib.pyplot as plt
import numpy as np 

# %matplotlib notebook

df = pd.read_csv('grouped_wells.csv', index_col = 0)

df.head()
# Out:
#   Well name Group Answer    Date  \
# 0     43629      Shallow  16-Jun
# 1       TH7      Shallow  16-Jun
# 2     35217      Shallow  16-Jun
# 3     35401      Shallow  16-Jun
# 4     97-21      Shallow  16-Jun
#
#    Corrected Groundwater Surface Elevation(masl)  Easting(m)  Northing(m)  \
# 0                                         946.19  645463.505  5867925.859
# 1                                         946.85  645461.893  5867883.754
# 2                                         948.82  645617.050  5867782.746
# 3                                         947.27  645466.248  5867809.039
# 4                                         947.19  645608.630  5867740.071
#
#    Screen Top(masl)  Screen Bot(masl)  screen mean(masl)  Group
# 0            948.70            945.70            947.200      0
# 1            946.21            945.36            945.785      0
# 2            948.80            945.80            947.300      0
# 3            947.82            944.82            946.320      0
# 4            947.14            943.14            945.140      0

# %%
def groupPlot(df, grouping1, grouping2, grouping3):
    group1 = df[df['Group'] == grouping1]
    group2 = df[df['Group'] == grouping2]
    group3 = df[df['Group'] == grouping3]

    northingSeries1 = group1['Northing(m)']

    eastingSeries1 = group1['Easting(m)']

    correctedGSE1 = group1['screen mean(masl)']


    northingSeries2 = group2['Northing(m)']

    eastingSeries2 = group2['Easting(m)']

    correctedGSE2 = group2['screen mean(masl)']


    northingSeries3 = group3['Northing(m)']

    eastingSeries3 = group3['Easting(m)']

    correctedGSE3 = group3['screen mean(masl)']

    
    fig = plt.figure(figsize=[10,5])
    ax = fig.add_subplot(111, projection='3d')

    for c, m, x, y, z in [('r', 'o', eastingSeries1, northingSeries1, correctedGSE1), ('b', 'o', eastingSeries2, northingSeries2, correctedGSE2), ('g', 'o', eastingSeries3, northingSeries3, correctedGSE3)]:

        ax.scatter(y, x, z, c=c, marker=m)

    ax.set_xlabel('Easting')
    ax.set_ylabel('Northing')
    ax.set_zlabel('Screen Midpoint')

    plt.show()

# %% [markdown]
# # Clustered Scattered Plot vs Expected Scatter Plot

# %%
df2 = pd.read_csv('clean_data_jun16.csv', index_col = 0)
df2.head()
# Out:
#              Group    Date  Corrected Groundwater Surface Elevation(masl)  \
# Well name
# 43629      Shallow  16-Jun                                         946.19
# TH7        Shallow  16-Jun                                         946.85
# 35217      Shallow  16-Jun                                         948.82
# 35401      Shallow  16-Jun                                         947.27
# 97-21      Shallow  16-Jun                                         947.19
#
#            Easting(m)  Northing(m)  Screen Top(masl)  Screen Bot(masl)  \
# Well name
# 43629      645463.505  5867925.859            948.70            945.70
# TH7        645461.893  5867883.754            946.21            945.36
# 35217      645617.050  5867782.746            948.80            945.80
# 35401      645466.248  5867809.039            947.82            944.82
# 97-21      645608.630  5867740.071            947.14            943.14
#
#            screen mean(masl)
# Well name
# 43629                947.200
# TH7                  945.785
# 35217                947.300
# 35401                946.320
# 97-21                945.140

# %%
groupPlot(df, 2, 1, 0)
groupPlot(df2, 'Deep', 'Medial', 'Shallow')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ### Vector Field Visualization
