# %% [markdown]
# # Hydrogeological automation: Clustering monitoring well elevations - a problem in environmental consulting

# %% [markdown]
# # Goal: Create horizontal groundwater flow contour map!
#
# # Horizontal groundwater flow can only be calculated for monitoring wells with approximately equal screen intervals.
#
# # Well 1 can be grouped with well 3, but well 2 should not be grouped with 1 or 3

# %%
from IPython.display import Image
Image(filename='aquifer_annotated.jpg')

# %% [markdown]
# # Well 1 can be grouped together with well 3 because their screen elevations are similar.
# # Well 2 cannot be grouped with well 1 or 3, because its screen interval is higher.

# %%
Image(filename='aquifer_annotated2.jpg')

# %% [markdown]
# # Our dataset: Real data of 113 monitoring wells with various screen interval depths.
# # The goal: Use Python to create clusters/groupings, based on screen interval elevation, and lateral proximity to each other.
# # Once groupings are made, we can create groundwater contour maps for each group using Python.

# %%
Image(filename='gw_map_example.png')

# %% [markdown]
# # Horizontal gw flow maps are created from monitoring wells of the same group (above)

# %% [markdown]
# # So what have we automated?
# # Our script can be applied to any Site or group of monitoring wells
# # E.g. If a consulting company picks up a new site, and has no pre-existing knowledge of the monitoring well network

# %% [markdown]
# # Improvements that can be made, if we had more time:
# # Incorporating geochemical data - associate monitoring wells with similar chemistries!
# # Incorporating lithology of the aquifer. E.g. Does the site have stratified lithology and different aquifers and aquitards? Does the site have fractured bedrock?
# # Creating a flexible algorithm that doesn't need number of groups specified (we assumed 3!)
